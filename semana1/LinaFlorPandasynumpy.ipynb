# %% [markdown]
# <a href="https://colab.research.google.com/github/gabrielasarria/Lina-Flor/blob/main/semana1/LinaFlorPandasynumpy.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Taller básico pandas - numpy

# %%
import pandas as pd

# %%
# Crear un dataframe que tenga 3 registros(filas) cada una debe contener el nombre de una cancion, el artista que la canta, y la duracion en segundos
nomsong = pd.Series(['sorry4that','Cualesesa', 'Cairo', 'Kingforaday'])
artistsong = pd.Series(['Feid','Feid', 'Karolg', 'Pierce the veil'])
durationsongseg = pd.Series([345,500,170,235])
df_song = pd.DataFrame({'Song':nomsong, 'Artist': artistsong, 'Duration Seg': durationsongseg})
# Out:
#           Song           Artist  Duration Seg
# 0   sorry4that             Feid           345
# 1    Cualesesa             Feid           500
# 2        Cairo           Karolg           170
# 3  Kingforaday  Pierce the veil           235

# %%
# Imprimir la cola del dataframe
df_song.tail()
# Out:
#           Song           Artist  Duration Seg
# 0   sorry4that             Feid           345
# 1    Cualesesa             Feid           500
# 2        Cairo           Karolg           170
# 3  Kingforaday  Pierce the veil           235

# %%
# Acceder a la columna duracion
df_song['Duration Seg']
# Out:
# 0    345
# 1    500
# 2    170
# 3    235
# Name: Duration Seg, dtype: int64

# %%
# Calcular el promedio de las duraciones
prom = df_song['Duration Seg'].mean()
prom
# Out:
# 312.5

# %%
# Obtener los nombres de las canciones que tengan duracion mayor que el promedio
df_song[df_song['Duration Seg'] > prom]['Song']
# Out:
# 0    sorry4that
# 1     Cualesesa
# Name: Song, dtype: object

# %%
# Agregar una columna al dataframe que contenga True si la duracion es mayor que 3 minutos
# y false si es menor

df_song['Duration > 3 min'] = df_song['Duration Seg'] > prom
df_song
# Out:
#           Song           Artist  Duration Seg  Duration > 3 min
# 0   sorry4that             Feid           345              True
# 1    Cualesesa             Feid           500              True
# 2        Cairo           Karolg           170             False
# 3  Kingforaday  Pierce the veil           235             False

# %%
# Convertir el dataframe a numpy array
arraysong = df_song.to_numpy()
arraysong
# Out:
# array([['sorry4that', 'Feid', 345, True],
#        ['Cualesesa', 'Feid', 500, True],
#        ['Cairo', 'Karolg', 170, False],
#        ['Kingforaday', 'Pierce the veil', 235, False]], dtype=object)

# %%
# Imprimir el shape del array

arraysong.shape
# Out:
# (4, 4)

# %%
# Hacer un reshape para convertir el arreglo de 3x3 a un arreglo de 12 elementos
arraysong.reshape(16)
# Out:
# array(['sorry4that', 'Feid', 345, True, 'Cualesesa', 'Feid', 500, True,
#        'Cairo', 'Karolg', 170, False, 'Kingforaday', 'Pierce the veil',
#        235, False], dtype=object)
